# %%
from bs4 import element


class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


node1 = Node(1)
node2 = Node(2)
node3 = Node(3)

head = node1
node1.next = node2
node2.next = node3

current = head
while current is not None:
    print(current.data)
    current = current.next
# Out:
# 1
# 2
# 3

# %%
list1 = [1,2,4]
list2 = [1,3,4]

# Definition for singly-linked list.
class ListNode:
     def __init__(self, val=0, next=None):
         self.val = val
         self.next = next



class Solution:
    def mergeTwoLists(self, list1, list2):
        dummy = ListNode()
        current = dummy

        while list1 and list2:
            if list1.val <= list2.val:
                current.next = list1
                list1 = list1.next
            else:
                current.next = list2
                list2 = list2.next

            current = current.next

        if list1:
            current.next = list1


        return dummy.next

# %%
class Node:
    def __init__(self):
        self.val = None
        self.next = None
    def __init__(self, data):
        self.val = data
        self.next = None

dummy = Node()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 9
#       5     def __init__(self, data):
#       6         self.val = data
#       7         self.next = None
#       8
# ----> 9 dummy = Node()
#      10 dummy.next = Node(1)
#      11 dummy.next.next = Node(2)
#
# TypeError: Node.__init__() missing 1 required positional argument: 'data'

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None


    def append_to_list(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        else:
            current = self.head

        while current.next:
            current = current.next

        current.next = new_node

    #ami chinta korsi
    def prepend_list1(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        else:
            current = new_node
            current.next = self.head
            self.head = current

    def add_to_first(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def display(self):
        elements = []

        current = self.head
        while current:
            elements.append(str(current.data))
            current = current.next

        print(" -> ".join(elements))


node1 = LinkedList()

node1.append_to_list(1)
node1.append_to_list(2)
node1.append_to_list(3)

print(node1.display())
# Out:
# 1 -> 2 -> 3
# None
